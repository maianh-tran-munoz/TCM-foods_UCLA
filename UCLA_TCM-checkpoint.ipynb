# %%
import requests

url = "https://www.uclahealth.org/sites/default/files/documents/e7/tcm-food-recommendations.pdf?f=f0952718"

response = requests.get(url)

with open("tcm_food_recommendations.pdf", "wb") as f:
    f.write(response.content)

print("Downloaded!")
# Out:
# Downloaded!

# %%
import pdfplumber
import pandas as pd
#create a empty notebook
text = ""

#+"\n": to start a new line
#copy the exact text page by page
#with automatically close the file when you finish
with pdfplumber.open("tcm_food_recommendations.pdf") as pdf:
    for page in pdf.pages:
        text += page.extract_text() + "\n"

print(text)
# Out:
# TRADITIONAL CHINESE
# MEDICINE FOOD
# RECOMMENDATIONS
# Cooling Foods
# Bitter, sour, green, blue, white
# Green leafy vegetables, celery, sprouts
# Seeds: sesame, flax, pumpkin, hemp
# Fruits: pear, watermelon, melons, pomegranate, berries, cucumber, banana
# Legumes: mung bean
# Fish, shellfish, and seafoods
# Teas: mint, chrysanthemum, flower
# Warming Foods
# Sweet, spicy, red, orange
# Root vegetables
# Nuts
# Spices: ginger, black pepper, cinnamon, turmeric, garlic
# Fruits: stone fruits, cherry, dates, mango
# Poultry, duck, lamb, beef
# Teas: ginger, cinnamon
# Moisten Dryness
# Fruit: pear, berries, goji berries, melon
# Legume: soybeans/tofu
# Seeds: sesame, flaxseed, hemp, pumpkin
# Snow fungus, wood ear
# Aloe
# Drinks: coconut water, honey
# Resolve Dampness
# Spices: nutmeg
# Grains: coix seed, millet, barley, buckwheat, quinoa
# Legumes: mung bean, adzuki beans
# Vegetables: cabbage, bean sprouts, bamboo shoots, seaweed
# Qi Tonic
# Whole grains: millet, oats, brown rice
# Chicken
# Root vegetables: sweet potato, carrots, beets, taro, Chinese yam
# Mung beans, adzuki beans
# Pumpkin, squashes
# Napa cabbage
# Fruits: pear, watermelon, honeydew, papaya, jujube dates
# Liquids: barley/buckwheat tea, bone broth
# Blood Tonic
# Protein: beef, lamb, salmon, liver, eggs
# Beans and legumes: Adzuki, kidney beans
# Seeds: black sesame, pine nut, walnut, chestnut
# Vegetables: collard greens, chives, beets, spinach, wheatgrass, spirulina, eggplant
# Fruit: cherry, goji berries, dates, figs, strawberries
# Bone broth
# Tea: nettles
# Fire Element
# Protein: eggs, lamb, beef, liver
# Vegetables: beets, chard
# Fruit: mulberry, jujube dates, longan, grapes, watermelon
# Lentils: kidney beans, chickpea, sesame
# Nuts: walnuts, pine nuts, almonds
# Spices: cinnamon
# Liquid: bone broth
# Teas: goji berry/jujube, longan, cinnamon
# Earth Element
# Protein: chicken
# Root vegetables: sweet potato, carrots, beets, taro, Chinese yam, pumpkin, squashes
# Fruits: jujube dates
# Whole grains: millet, oats, brown rice
# Legumes: Adzuki beans and mung beans
# Liquid: bone broth
# Teas: barley or buckwheat tea
# Metal Element
# Vegetables: mountain yam, radish, daikon, lotus root, Napa cabbage
# Fruit: apple, pear, banana, coconut
# Grain: millet, buckwheat
# Nuts: almond, walnut
# Spices: onion, scallion, garlic, ginger, star anise
# Liquids: bone broth, soy milk, almond milk
# Teas: ginger, dried pear
# Water Element
# Protein: duck, squid, lamb, venison, shellfish
# Vegetables: dark leafy greens, mushrooms, seaweed, kombu
# Fruit: blackberry, mulberry, cherry, cranberry
# Grain/legume: black rice, black kidney bean
# Seeds: black sesame
# Spice: cinnamon, star anise
# Liquid: bone broth, royal jelly
# Teas: black sesame, mulberry
# Wood Element
# Protein: shellfish
# Vegetables: dark leafy greens, dandelion, celery, sprouts
# Fruit: mango, pineapple, plum, lemon, lime, goji berries
# Legumes: mung bean
# Spices: garlic, green onion, cilantro
# Teas: chrysanthemum, rose

# %%
# Function headings we want to recognize
functions = [
    "Cooling Foods",
    "Warming Foods",
    "Moisten Dryness",
    "Resolve Dampness",
    "Qi Tonic",
    "Blood Tonic"
    "Fire Element",
    "Earth Element",
    "Metal Element",
    "Water Element",
    "Wood Element"
]
#lines = [] is a list
#if line.strip(): only include if it wasn't empty after stripping
#splitlines(): break text into a list
#strip(): remove space from both endings of the string
lines = [line.strip() for line in text.strip().splitlines() if line.strip()]

current_function = None

print("| Food | Food Category | Function |")
print("| ---- | ---- | ---- |")


for line in lines:

    for function in functions:
        if line.startswith(function):
            current_function = function
            break


    # Ignore the title at the beginning
    if line in [
        "TRADITIONAL CHINESE",
        "MEDICINE FOOD",
        "RECOMMENDATIONS"
    ]:
        continue

    # Ignore descriptive/color lines
    if line in [
        "Bitter, sour, green, blue, white",
        "Sweet, spicy, red, orange"
    ]:
        continue

    # Category: foods
    
    if ":" in line:
        #split(":",1): use colon ":" as a cutting point
        #and stop after one "1" split
        #(example) Teas: goji berry/jujube, longan, cinnamon
        #Teas will be the category
        category, foods = line.split(":", 1)

        for food in foods.split(","):
            
            food = food.strip()

            if food:
                #f": formatted string
                #replaces the things inside {} with their values.
                print(
                    f"| {food} | {category.strip()} | {current_function} |"
                )

    # Lines without a category
    else:
        for food in line.split(","):
            food = food.strip()

            if food:
                print(
                    f"| {food} | General | {current_function} |"
                )
# Out:
# | Food | Food Category | Function |
# | ---- | ---- | ---- |
# | Cooling Foods | General | Cooling Foods |
# | Green leafy vegetables | General | Cooling Foods |
# | celery | General | Cooling Foods |
# | sprouts | General | Cooling Foods |
# | sesame | Seeds | Cooling Foods |
# | flax | Seeds | Cooling Foods |
# | pumpkin | Seeds | Cooling Foods |
# | hemp | Seeds | Cooling Foods |
# | pear | Fruits | Cooling Foods |
# | watermelon | Fruits | Cooling Foods |
# | melons | Fruits | Cooling Foods |
# | pomegranate | Fruits | Cooling Foods |
# | berries | Fruits | Cooling Foods |
# | cucumber | Fruits | Cooling Foods |
# | banana | Fruits | Cooling Foods |
# | mung bean | Legumes | Cooling Foods |
# | Fish | General | Cooling Foods |
# | shellfish | General | Cooling Foods |
# | and seafoods | General | Cooling Foods |
# | mint | Teas | Cooling Foods |
# | chrysanthemum | Teas | Cooling Foods |
# | flower | Teas | Cooling Foods |
# | Warming Foods | General | Warming Foods |
# | Root vegetables | General | Warming Foods |
# | Nuts | General | Warming Foods |
# | ginger | Spices | Warming Foods |
# | black pepper | Spices | Warming Foods |
# | cinnamon | Spices | Warming Foods |
# | turmeric | Spices | Warming Foods |
# | garlic | Spices | Warming Foods |
# | stone fruits | Fruits | Warming Foods |
# | squid | Protein | Blood Tonic |
# | lamb | Protein | Blood Tonic |
# | venison | Protein | Blood Tonic |
# | shellfish | Protein | Blood Tonic |
# | dark leafy greens | Vegetables | Blood Tonic |
# | mushrooms | Vegetables | Blood Tonic |
# | seaweed | Vegetables | Blood Tonic |
# | kombu | Vegetables | Blood Tonic |
# | blackberry | Fruit | Blood Tonic |
# | mulberry | Fruit | Blood Tonic |
# | cherry | Fruit | Blood Tonic |
# | cranberry | Fruit | Blood Tonic |
# | black rice | Grain/legume | Blood Tonic |
# | black kidney bean | Grain/legume | Blood Tonic |
# | black sesame | Seeds | Blood Tonic |
# | cinnamon | Spice | Blood Tonic |
# | star anise | Spice | Blood Tonic |
# | bone broth | Liquid | Blood Tonic |
# | royal jelly | Liquid | Blood Tonic |
# | black sesame | Teas | Blood Tonic |
# | mulberry | Teas | Blood Tonic |
# | Wood Element | General | Blood Tonic |
# | shellfish | Protein | Blood Tonic |
# | dark leafy greens | Vegetables | Blood Tonic |
# | dandelion | Vegetables | Blood Tonic |
# | celery | Vegetables | Blood Tonic |
# | sprouts | Vegetables | Blood Tonic |
# | mango | Fruit | Blood Tonic |
# | pineapple | Fruit | Blood Tonic |
# | plum | Fruit | Blood Tonic |
# | lemon | Fruit | Blood Tonic |
# | lime | Fruit | Blood Tonic |
# | goji berries | Fruit | Blood Tonic |
# | mung bean | Legumes | Blood Tonic |
# | garlic | Spices | Blood Tonic |
# | green onion | Spices | Blood Tonic |
# | cilantro | Spices | Blood Tonic |
# | chrysanthemum | Teas | Blood Tonic |
# | rose | Teas | Blood Tonic |

# %%
rows = []
# Function headings we want to recognize
functions = [
    "Cooling Foods",
    "Warming Foods",
    "Moisten Dryness",
    "Resolve Dampness",
    "Qi Tonic",
    "Blood Tonic",
    "Fire Element",
    "Earth Element",
    "Metal Element",
    "Water Element",
    "Wood Element"
]
#lines = [] is a list
#if line.strip(): only include if it wasn't empty after stripping
#splitlines(): break text into a list
#strip(): remove space from both endings of the string
lines = [line.strip() for line in text.strip().splitlines() if line.strip()]

current_function = None

print("| Food | Food Category | Function |")
print("| ---- | ---- | ---- |")


for line in lines:

    #is this the function heading?
    if line in functions:
        current_function = line
        continue


    # Ignore the title at the beginning
    if line in [
        "TRADITIONAL CHINESE",
        "MEDICINE FOOD",
        "RECOMMENDATIONS"
    ]:
        continue

    # Ignore descriptive/color lines
    if line in [
        "Bitter, sour, green, blue, white",
        "Sweet, spicy, red, orange"
    ]:
        continue

    # Category: foods
    
    if ":" in line:
        #split(":",1): use colon ":" as a cutting point
        #and stop after one "1" split
        #(example) Teas: goji berry/jujube, longan, cinnamon
        #Teas will be the category
        category, foods = line.split(":", 1)

        for food in foods.split(","):
            
            food = food.strip()
            if food:
                    rows.append({
                        "Food": food,
                        "Food Category": category.strip(),
                        "Function": current_function
                    })
            # if food:
            #     #f": formatted string
            #     #replaces the things inside {} with their values.
            #     print(
            #         f"| {food} | {category.strip()} | {current_function} |"
            #     )

    # Lines without a category
    else:
        for food in line.split(","):
            food = food.strip()
            if food:
                    rows.append({
                        "Food": food,
                        "Food Category": category.strip(),
                        "Function": current_function
                    })

            # if food:
            #     print(
            #         f"| {food} | General | {current_function} |"
            #     )
print (rows)
# Out:
# | Food | Food Category | Function |
# | ---- | ---- | ---- |
# [{'Food': 'Green leafy vegetables', 'Food Category': 'Teas', 'Function': 'Cooling Foods'}, {'Food': 'celery', 'Food Category': 'Teas', 'Function': 'Cooling Foods'}, {'Food': 'sprouts', 'Food Category': 'Teas', 'Function': 'Cooling Foods'}, {'Food': 'sesame', 'Food Category': 'Seeds', 'Function': 'Cooling Foods'}, {'Food': 'flax', 'Food Category': 'Seeds', 'Function': 'Cooling Foods'}, {'Food': 'pumpkin', 'Food Category': 'Seeds', 'Function': 'Cooling Foods'}, {'Food': 'hemp', 'Food Category': 'Seeds', 'Function': 'Cooling Foods'}, {'Food': 'pear', 'Food Category': 'Fruits', 'Function': 'Cooling Foods'}, {'Food': 'watermelon', 'Food Category': 'Fruits', 'Function': 'Cooling Foods'}, {'Food': 'melons', 'Food Category': 'Fruits', 'Function': 'Cooling Foods'}, {'Food': 'pomegranate', 'Food Category': 'Fruits', 'Function': 'Cooling Foods'}, {'Food': 'berries', 'Food Category': 'Fruits', 'Function': 'Cooling Foods'}, {'Food': 'cucumber', 'Food Category': 'Fruits', 'Function': 'Cooling Foods'}, {'Food': 'banana', 'Food Category': 'Fruits', 'Function': 'Cooling Foods'}, {'Food': 'mung bean', 'Food Category': 'Legumes', 'Function': 'Cooling Foods'}, {'Food': 'Fish', 'Food Category': 'Legumes', 'Function': 'Cooling Foods'}, {'Food': 'shellfish', 'Food Category': 'Legumes', 'Function': 'Cooling Foods'}, {'Food': 'and seafoods', 'Food Category': 'Legumes', 'Function': 'Cooling Foods'}, {'Food': 'mint', 'Food Category': 'Teas', 'Function': 'Cooling Foods'}, {'Food': 'chrysanthemum', 'Food Category': 'Teas', 'Function': 'Cooling Foods'}, {'Food': 'flower', 'Food Category': 'Teas', 'Function': 'Cooling Foods'}, {'Food': 'Root vegetables', 'Food Category': 'Teas', 'Function': 'Warming Foods'}, {'Food': 'Nuts', 'Food Category': 'Teas', 'Function': 'Warming Foods'}, {'Food': 'ginger', 'Food Category': 'Spices', 'Function': 'Warming Foods'}, {'Food': 'black pepper', 'Food Category': 'Spices', 'Function': 'Warming Foods'}, {'Food': 'cinnamon', 'Food Category': 'Spices', 'Function': 'Warming Foods'}, {'Food': 'turmeric', 'Food Category': 'Spices', 'Function': 'Warming Foods'}, {'Food': 'garlic', 'Food Category': 'Spices', 'Function': 'Warming Foods'}, {'Food': 'stone fruits', 'Food Category': 'Fruits', 'Function': 'Warming Foods'}, {'Food': 'cherry', 'Food Category': 'Fruits', 'Function': 'Warming Foods'}, {'Food': 'dates', 'Food Category': 'Fruits', 'Function': 'Warming Foods'}, {'Food': 'mango', 'Food Category': 'Fruits', 'Function': 'Warming Foods'}, {'Food': 'Poultry', 'Food Category': 'Fruits', 'Function': 'Warming Foods'}, {'Food': 'duck', 'Food Category': 'Fruits', 'Function': 'Warming Foods'}, {'Food': 'lamb', 'Food Category': 'Fruits', 'Function': 'Warming Foods'}, {'Food': 'beef', 'Food Category': 'Fruits', 'Function': 'Warming Foods'}, {'Food': 'ginger', 'Food Category': 'Teas', 'Function': 'Warming Foods'}, {'Food': 'cinnamon', 'Food Category': 'Teas', 'Function': 'Warming Foods'}, {'Food': 'pear', 'Food Category': 'Fruit', 'Function': 'Moisten Dryness'}, {'Food': 'berries', 'Food Category': 'Fruit', 'Function': 'Moisten Dryness'}, {'Food': 'goji berries', 'Food Category': 'Fruit', 'Function': 'Moisten Dryness'}, {'Food': 'melon', 'Food Category': 'Fruit', 'Function': 'Moisten Dryness'}, {'Food': 'soybeans/tofu', 'Food Category': 'Legume', 'Function': 'Moisten Dryness'}, {'Food': 'sesame', 'Food Category': 'Seeds', 'Function': 'Moisten Dryness'}, {'Food': 'flaxseed', 'Food Category': 'Seeds', 'Function': 'Moisten Dryness'}, {'Food': 'hemp', 'Food Category': 'Seeds', 'Function': 'Moisten Dryness'}, {'Food': 'pumpkin', 'Food Category': 'Seeds', 'Function': 'Moisten Dryness'}, {'Food': 'Snow fungus', 'Food Category': 'Seeds', 'Function': 'Moisten Dryness'}, {'Food': 'wood ear', 'Food Category': 'Seeds', 'Function': 'Moisten Dryness'}, {'Food': 'Aloe', 'Food Category': 'Seeds', 'Function': 'Moisten Dryness'}, {'Food': 'coconut water', 'Food Category': 'Drinks', 'Function': 'Moisten Dryness'}, {'Food': 'honey', 'Food Category': 'Drinks', 'F ...

# %%
import pandas as pd
df = pd.DataFrame(rows)
#insert a explicit ID
# df.insert(0, "ID", ...):Put a new column at position 0, call it "ID".
# len(df):How many rows are in df= 209
#range (1,210)
#starts at 1 and stop before 210
df.insert(0, "ID", range(1, len(df) + 1))
#capitalized the first letter of Food
#pandas Series doesn't have a regular .capitalize() method.
#.str:"Apply the string operation to the strings inside this column."
#if food has "and", replace it with ""
df["Food"] = df["Food"].str.replace("and ", "", regex=False)
df["Food"] = df["Food"].str.capitalize()
df
# Out:
#       ID                    Food Food Category       Function
# 0      1  Green leafy vegetables          Teas  Cooling Foods
# 1      2                  Celery          Teas  Cooling Foods
# 2      3                 Sprouts          Teas  Cooling Foods
# 3      4                  Sesame         Seeds  Cooling Foods
# 4      5                    Flax         Seeds  Cooling Foods
# ..   ...                     ...           ...            ...
# 204  205                  Garlic        Spices   Wood Element
# 205  206             Green onion        Spices   Wood Element
# 206  207                Cilantro        Spices   Wood Element
# 207  208           Chrysanthemum          Teas   Wood Element
# 208  209                    Rose          Teas   Wood Element
#
# [209 rows x 4 columns]

# %%
df.to_excel("TCM_food_recommendations_v4.xlsx", index=False)
import os
#getcwd(): return current working directory
print(os.getcwd())
# Out:
# C:\Users\rodol

# %%
#dropna():drop any row containing at least one missing value.
#unique():extract on one-of-a-kind item
functions = df["Function"].dropna().unique()
#enumerate():allows you to loop through an iterable (like a list, tuple, or string) 
#while automatically keeping track of the index of each item.
#(functions,1): start counting at 1, instead of 0
for i, function in enumerate(functions, 1):
    print(f"{i}. {function}")
# Out:
# 1. Cooling Foods
# 2. Warming Foods
# 3. Moisten Dryness
# 4. Resolve Dampness
# 5. Qi Tonic
# 6. Blood Tonic
# 7. Fire Element
# 8. Earth Element
# 9. Metal Element
# 10. Water Element
# 11. Wood Element

# %%
choice = int(input("Enter the number of the function you're interested in: "))
#Python indexes from 0, human indexes from 1, 
#so we need to convert "choice" to Python index
selected_function = functions[choice - 1]

print(f"\nYou selected: {selected_function}")
# Out:
# Enter the number of the function you're interested in:  3
# You selected: Moisten Dryness

# %%
#Take my original df, and keep only the rows where the checklist says True
#save it to a smaller df, named "recommendations"
recommendations = df[df["Function"] == selected_function]

recommendations
# Out:
#     ID           Food Food Category         Function
# 38  39           Pear         Fruit  Moisten Dryness
# 39  40        Berries         Fruit  Moisten Dryness
# 40  41   Goji berries         Fruit  Moisten Dryness
# 41  42          Melon         Fruit  Moisten Dryness
# 42  43  Soybeans/tofu        Legume  Moisten Dryness
# 43  44         Sesame         Seeds  Moisten Dryness
# 44  45       Flaxseed         Seeds  Moisten Dryness
# 45  46           Hemp         Seeds  Moisten Dryness
# 46  47        Pumpkin         Seeds  Moisten Dryness
# 47  48    Snow fungus         Seeds  Moisten Dryness
# 48  49       Wood ear         Seeds  Moisten Dryness
# 49  50           Aloe         Seeds  Moisten Dryness
# 50  51  Coconut water        Drinks  Moisten Dryness
# 51  52          Honey        Drinks  Moisten Dryness

# %%
#output prettier
#f-string: Replace anything inside {} with its value
# \n: is the newline character escape sequence, 
#used to insert a line break within a string literal *ENter, enter*
print(f"\nFoods listed under {selected_function}:\n")
#df.iterrows(): loop through the rows of a DataFrame, yielding the index and the row data as a Series for each iteration.
#_: means I don't want the index
for _, row in recommendations.iterrows():
    print(f"- {row['Food']} ({row['Food Category']})")
# Out:
# Foods listed under Moisten Dryness:
#
# - Pear (Fruit)
# - Berries (Fruit)
# - Goji berries (Fruit)
# - Melon (Fruit)
# - Soybeans/tofu (Legume)
# - Sesame (Seeds)
# - Flaxseed (Seeds)
# - Hemp (Seeds)
# - Pumpkin (Seeds)
# - Snow fungus (Seeds)
# - Wood ear (Seeds)
# - Aloe (Seeds)
# - Coconut water (Drinks)
# - Honey (Drinks)

# %%
# What would you like to explore?

# 1. Find foods by TCM function
# 2. Find foods by food category
# 3. Find where a particular food appears
# 4. See foods that appear in multiple TCM functions
# 5. Exit

# You could eventually add things such as:

# Food
# Food Category
# TCM Function
# Protein
# Fiber
# Vitamin C
# Iron
# Calories
# ...

# Then your program could distinguish between:

# "This food is listed under Blood Tonic in the UCLA TCM resource."

# and:

# "This food also provides iron/fiber/etc."

# That distinction is important because the TCM classification and modern nutritional composition aren't the same thing.

# Current U.S. Dietary Guidelines emphasize dietary patterns containing 
# vegetables, fruits, whole grains, legumes, seafood, nuts, seeds and 
# other nutrient-dense foods rather than relying on individual "magic" foods.

# %%
#food search
food = input("Enter a food: ").strip().lower()

results = df[
    df["Food"].str.lower() == food
]

results
# Out:
# Enter a food:  pear
#       ID  Food Food Category         Function
# 7      8  Pear        Fruits    Cooling Foods
# 38    39  Pear         Fruit  Moisten Dryness
# 78    79  Pear        Fruits         Qi Tonic
# 153  154  Pear         Fruit    Metal Element
